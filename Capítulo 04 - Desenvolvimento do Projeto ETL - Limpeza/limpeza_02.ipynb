# %%
import pandas as pd

# %%
df = pd.read_csv("ocorrencia_2010_2020_modificada.csv", sep=",", parse_dates=['ocorrencia_dia'], dayfirst=True)

# %%
df.head(5)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0

# %%
df.loc[df.ocorrencia_aerodromo == '****', [ocorrencia_aerodromo]] = pd.NA

# %%
df.replace(['**', '###!', '####', '****', '******', 'NULL'], pd.NA, inplace=True)

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5734              79769               79769          INCIDENTE GRAVE
# 5735              79804               79804                INCIDENTE
# 5736              79757               79757          INCIDENTE GRAVE
# 5737              79802               79802                INCIDENTE
# 5738              79756               79756          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 5734       MANOEL URBANO            AC                 SIMB     2020-12-29
# 5735            CAMPINAS            SP                 SBKP     2020-12-29
# 5736   LAGOA DA CONFUSÃO            TO                 <NA>     2020-12-30
# 5737      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5738           VICENTINA            MS                 <NA>     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 5734        18:30:00                    0
# 5735        19:00:00                    0
# 5736        18:30:00                    0
# 5737        00:54:00                    0
# 5738        09:00:00                    0
#
# [5739 rows x 9 columns]

# %%
df.isna()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2  ocorrencia_classificacao  \
# 0                 False               False                     False
# 1                 False               False                     False
# 2                 False               False                     False
# 3                 False               False                     False
# 4                 False               False                     False
# ...                 ...                 ...                       ...
# 5734              False               False                     False
# 5735              False               False                     False
# 5736              False               False                     False
# 5737              False               False                     False
# 5738              False               False                     False
#
#       ocorrencia_cidade  ocorrencia_uf  ocorrencia_aerodromo  ocorrencia_dia  \
# 0                 False          False                  True           False
# 1                 False          False                 False           False
# 2                 False          False                 False           False
# 3                 False          False                  True           False
# 4                 False          False                 False           False
# ...                 ...            ...                   ...             ...
# 5734              False          False                 False           False
# 5735              False          False                 False           False
# 5736              False          False                  True           False
# 5737              False          False                 False           False
# 5738              False          False                  True           False
#
#       ocorrencia_hora  total_recomendacoes
# 0               False                False
# 1               False                False
# 2               False                False
# 3               False                False
# 4               False                False
# ...               ...                  ...
# 5734            False                False
# 5735            False                False
# 5736            False                False
# 5737            False                False
# 5738            False                False
#
# [5739 rows x 9 columns]

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2194
# ocorrencia_dia                 0
# ocorrencia_hora                0
# total_recomendacoes            0
# dtype: int64

# %%
df.isnull()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2  ocorrencia_classificacao  \
# 0                 False               False                     False
# 1                 False               False                     False
# 2                 False               False                     False
# 3                 False               False                     False
# 4                 False               False                     False
# ...                 ...                 ...                       ...
# 5734              False               False                     False
# 5735              False               False                     False
# 5736              False               False                     False
# 5737              False               False                     False
# 5738              False               False                     False
#
#       ocorrencia_cidade  ocorrencia_uf  ocorrencia_aerodromo  ocorrencia_dia  \
# 0                 False          False                  True           False
# 1                 False          False                 False           False
# 2                 False          False                 False           False
# 3                 False          False                  True           False
# 4                 False          False                 False           False
# ...                 ...            ...                   ...             ...
# 5734              False          False                 False           False
# 5735              False          False                 False           False
# 5736              False          False                  True           False
# 5737              False          False                 False           False
# 5738              False          False                  True           False
#
#       ocorrencia_hora  total_recomendacoes
# 0               False                False
# 1               False                False
# 2               False                False
# 3               False                False
# 4               False                False
# ...               ...                  ...
# 5734            False                False
# 5735            False                False
# 5736            False                False
# 5737            False                False
# 5738            False                False
#
# [5739 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2194
# ocorrencia_dia                 0
# ocorrencia_hora                0
# total_recomendacoes            0
# dtype: int64

# %%
df.fillna(0)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5734              79769               79769          INCIDENTE GRAVE
# 5735              79804               79804                INCIDENTE
# 5736              79757               79757          INCIDENTE GRAVE
# 5737              79802               79802                INCIDENTE
# 5738              79756               79756          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                    0     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                    0     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 5734       MANOEL URBANO            AC                 SIMB     2020-12-29
# 5735            CAMPINAS            SP                 SBKP     2020-12-29
# 5736   LAGOA DA CONFUSÃO            TO                    0     2020-12-30
# 5737      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5738           VICENTINA            MS                    0     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 5734        18:30:00                    0
# 5735        19:00:00                    0
# 5736        18:30:00                    0
# 5737        00:54:00                    0
# 5738        09:00:00                    0
#
# [5739 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2194
# ocorrencia_dia                 0
# ocorrencia_hora                0
# total_recomendacoes            0
# dtype: int64

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0

# %%
df.replace([10], pd.NA, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2194
# ocorrencia_dia                 0
# ocorrencia_hora                0
# total_recomendacoes            2
# dtype: int64

# %%
df.fillna(value = {'total_recomendacoes': 10}, inplace = True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2194
# ocorrencia_dia                 0
# ocorrencia_hora                0
# total_recomendacoes            0
# dtype: int64

# %%
df['total_recomendacoes_bkp'] = df.total_recomendacoes

# %%
df.head()
# Out:
#   codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0             40211              40211                INCIDENTE
# 1             40349              40349                INCIDENTE
# 2             40351              40351                INCIDENTE
# 3             39527              39527                 ACIDENTE
# 4             40324              40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes  total_recomendacoes_bkp
# 0        12:00:00                    0                        0
# 1        11:05:00                    0                        0
# 2        03:00:00                    0                        0
# 3        17:30:00                    0                        0
# 4        19:25:00                    0                        0

# %%
df.drop(['total_recomendacoes_bkp'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#   codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0             40211              40211                INCIDENTE
# 1             40349              40349                INCIDENTE
# 2             40351              40351                INCIDENTE
# 3             39527              39527                 ACIDENTE
# 4             40324              40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0

# %%
df.dropna()
# Out:
#      codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 1                40349              40349                INCIDENTE
# 2                40351              40351                INCIDENTE
# 4                40324              40324                INCIDENTE
# 6                40215              40215                INCIDENTE
# 8                39156              39156          INCIDENTE GRAVE
# ...                ...                ...                      ...
# 5730             79800              79800                INCIDENTE
# 5731             79824              79824                 ACIDENTE
# 5734             79769              79769          INCIDENTE GRAVE
# 5735             79804              79804                INCIDENTE
# 5737             79802              79802                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1                BELÉM            PA                 SBBE     2010-01-03
# 2       RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 4              PELOTAS            RS                 SBPK     2010-01-05
# 6                COARI            AM                 SBUY     2010-01-07
# 8             CASCAVEL            PR                 SBCA     2010-01-10
# ...                ...           ...                  ...            ...
# 5730         SÃO PAULO            SP                 SBMT     2020-12-28
# 5731     RIO PARANAÍBA            MG                 SNRP     2020-12-28
# 5734     MANOEL URBANO            AC                 SIMB     2020-12-29
# 5735          CAMPINAS            SP                 SBKP     2020-12-29
# 5737    RIO DE JANEIRO            RJ                 SBGL     2020-12-30
#
#      ocorrencia_hora  total_recomendacoes
# 1           11:05:00                    0
# 2           03:00:00                    0
# 4           19:25:00                    0
# 6           18:40:00                    0
# 8           23:15:00                    2
# ...              ...                  ...
# 5730        10:15:00                    0
# 5731        17:00:00                    0
# 5734        18:30:00                    0
# 5735        19:00:00                    0
# 5737        00:54:00                    0
#
# [3545 rows x 9 columns]

# %%
df.head()
# Out:
#   codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0             40211              40211                INCIDENTE
# 1             40349              40349                INCIDENTE
# 2             40351              40351                INCIDENTE
# 3             39527              39527                 ACIDENTE
# 4             40324              40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0

# %%
df.dropna(subset = ['ocorrencia_uf'])
# Out:
#      codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                40211              40211                INCIDENTE
# 1                40349              40349                INCIDENTE
# 2                40351              40351                INCIDENTE
# 3                39527              39527                 ACIDENTE
# 4                40324              40324                INCIDENTE
# ...                ...                ...                      ...
# 5734             79769              79769          INCIDENTE GRAVE
# 5735             79804              79804                INCIDENTE
# 5736             79757              79757          INCIDENTE GRAVE
# 5737             79802              79802                INCIDENTE
# 5738             79756              79756          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 5734       MANOEL URBANO            AC                 SIMB     2020-12-29
# 5735            CAMPINAS            SP                 SBKP     2020-12-29
# 5736   LAGOA DA CONFUSÃO            TO                 <NA>     2020-12-30
# 5737      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5738           VICENTINA            MS                 <NA>     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 5734        18:30:00                    0
# 5735        19:00:00                    0
# 5736        18:30:00                    0
# 5737        00:54:00                    0
# 5738        09:00:00                    0
#
# [5739 rows x 9 columns]

# %%
df.drop_duplicates()
# Out:
#      codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                40211              40211                INCIDENTE
# 1                40349              40349                INCIDENTE
# 2                40351              40351                INCIDENTE
# 3                39527              39527                 ACIDENTE
# 4                40324              40324                INCIDENTE
# ...                ...                ...                      ...
# 5734             79769              79769          INCIDENTE GRAVE
# 5735             79804              79804                INCIDENTE
# 5736             79757              79757          INCIDENTE GRAVE
# 5737             79802              79802                INCIDENTE
# 5738             79756              79756          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 5734       MANOEL URBANO            AC                 SIMB     2020-12-29
# 5735            CAMPINAS            SP                 SBKP     2020-12-29
# 5736   LAGOA DA CONFUSÃO            TO                 <NA>     2020-12-30
# 5737      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5738           VICENTINA            MS                 <NA>     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 5734        18:30:00                    0
# 5735        19:00:00                    0
# 5736        18:30:00                    0
# 5737        00:54:00                    0
# 5738        09:00:00                    0
#
# [5739 rows x 9 columns]

# %%
df.head()
# Out:
#   codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0             40211              40211                INCIDENTE
# 1             40349              40349                INCIDENTE
# 2             40351              40351                INCIDENTE
# 3             39527              39527                 ACIDENTE
# 4             40324              40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0

# %%
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#      codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                40211              40211                INCIDENTE
# 1                40349              40349                INCIDENTE
# 2                40351              40351                INCIDENTE
# 3                39527              39527                 ACIDENTE
# 4                40324              40324                INCIDENTE
# ...                ...                ...                      ...
# 5734             79769              79769          INCIDENTE GRAVE
# 5735             79804              79804                INCIDENTE
# 5736             79757              79757          INCIDENTE GRAVE
# 5737             79802              79802                INCIDENTE
# 5738             79756              79756          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 5734       MANOEL URBANO            AC                 SIMB     2020-12-29
# 5735            CAMPINAS            SP                 SBKP     2020-12-29
# 5736   LAGOA DA CONFUSÃO            TO                 <NA>     2020-12-30
# 5737      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5738           VICENTINA            MS                 <NA>     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 5734        18:30:00                    0
# 5735        19:00:00                    0
# 5736        18:30:00                    0
# 5737        00:54:00                    0
# 5738        09:00:00                    0
#
# [5739 rows x 9 columns]
