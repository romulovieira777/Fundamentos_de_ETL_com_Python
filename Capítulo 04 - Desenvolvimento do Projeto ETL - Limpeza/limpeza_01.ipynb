# %%
import pandas as pd

# %%
df = pd.read_csv("ocorrencia_2010_2020_modificada.csv", sep=",", parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head(5)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0

# %%
df.loc[1, 'ocorrencia_cidade']
# Out:
# 'BELÉM'

# %%
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
#
#   ocorrencia_hora  total_recomendacoes
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0

# %%
df.loc[[10, 40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 40              39158               39158                INCIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10  SÃO PEDRO DO SUL            RS                 ****     2010-01-10
# 40             BELÉM            PA                 ****     2010-01-28
#
#    ocorrencia_hora  total_recomendacoes
# 10        21:30:00                    0
# 40        16:00:00                    0

# %%
df.loc[:,'ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 5734         MANOEL URBANO
# 5735              CAMPINAS
# 5736     LAGOA DA CONFUSÃO
# 5737        RIO DE JANEIRO
# 5738             VICENTINA
# Name: ocorrencia_cidade, Length: 5739, dtype: object

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
df.set_index('codigo_ocorrencia', inplace=True)

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_uf  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE            RJ
# 40349                           40349                INCIDENTE            PA
# 40351                           40351                INCIDENTE            RJ
# 39527                           39527                 ACIDENTE            MT
# 40324                           40324                INCIDENTE            RS
#
#                   ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# codigo_ocorrencia
# 40211                             ****     2010-01-03        12:00:00
# 40349                             SBBE     2010-01-03        11:05:00
# 40351                             SBRJ     2010-01-03        03:00:00
# 39527                             ****     2010-01-04        17:30:00
# 40324                             SBPK     2010-01-05        19:25:00
#
#                    total_recomendacoes
# codigo_ocorrencia
# 40211                                0
# 40349                                0
# 40351                                0
# 39527                                0
# 40324                                0

# %%
df.loc[40324]
# Out:
# codigo_ocorrencia2                        40324
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_uf                                RS
# ocorrencia_aerodromo                       SBPK
# ocorrencia_dia              2010-01-05 00:00:00
# ocorrencia_hora                        19:25:00
# total_recomendacoes                           0
# Name: 40324, dtype: object

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_uf  \
# 0               40211                INCIDENTE            RJ
# 1               40349                INCIDENTE            PA
# 2               40351                INCIDENTE            RJ
# 3               39527                 ACIDENTE            MT
# 4               40324                INCIDENTE            RS
#
#   ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0                 ****     2010-01-03        12:00:00                    0
# 1                 SBBE     2010-01-03        11:05:00                    0
# 2                 SBRJ     2010-01-03        03:00:00                    0
# 3                 ****     2010-01-04        17:30:00                    0
# 4                 SBPK     2010-01-05        19:25:00                    0

# %%
df.loc[0, 'ocorrencia_aerodromo'] = ''

# %%
df.head(1)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_uf  \
# 0               40211                INCIDENTE            RJ
#
#   ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0                          2010-01-03        12:00:00                    0

# %%
df.loc[1] = 20

# %%
df.head(2)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_uf  \
# 0               40211                INCIDENTE            RJ
# 1                  20                       20            20
#
#   ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0                       2010-01-03 00:00:00        12:00:00
# 1                   20                   20              20
#
#    total_recomendacoes
# 0                    0
# 1                   20

# %%
df.loc[:, 'total_recomendacoes'] = 10

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_uf  \
# 0               40211                INCIDENTE            RJ
# 1                  20                       20            20
# 2               40351                INCIDENTE            RJ
# 3               39527                 ACIDENTE            MT
# 4               40324                INCIDENTE            RS
#
#   ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0                       2010-01-03 00:00:00        12:00:00
# 1                   20                   20              20
# 2                 SBRJ  2010-01-03 00:00:00        03:00:00
# 3                 ****  2010-01-04 00:00:00        17:30:00
# 4                 SBPK  2010-01-05 00:00:00        19:25:00
#
#    total_recomendacoes
# 0                   10
# 1                   10
# 2                   10
# 3                   10
# 4                   10

# %%
df['ocorrencia_uf_bkp'] = df.ocorrencia_uf

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_uf  \
# 0                  40211                INCIDENTE            RJ
# 1                     20                       20            20
# 2                  40351                INCIDENTE            RJ
# 3                  39527                 ACIDENTE            MT
# 4                  40324                INCIDENTE            RS
# ...                  ...                      ...           ...
# 5734               79769          INCIDENTE GRAVE            AC
# 5735               79804                INCIDENTE            SP
# 5736               79757          INCIDENTE GRAVE            TO
# 5737               79802                INCIDENTE            RJ
# 5738               79756          INCIDENTE GRAVE            MS
#
#      ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0                          2010-01-03 00:00:00        12:00:00
# 1                      20                   20              20
# 2                    SBRJ  2010-01-03 00:00:00        03:00:00
# 3                    ****  2010-01-04 00:00:00        17:30:00
# 4                    SBPK  2010-01-05 00:00:00        19:25:00
# ...                   ...                  ...             ...
# 5734                 SIMB  2020-12-29 00:00:00        18:30:00
# 5735                 SBKP  2020-12-29 00:00:00        19:00:00
# 5736                 ****  2020-12-30 00:00:00        18:30:00
# 5737                 SBGL  2020-12-30 00:00:00        00:54:00
# 5738                 ****  2020-12-31 00:00:00        09:00:00
#
#       total_recomendacoes ocorrencia_uf_bkp
# 0                      10                RJ
# 1                      10                20
# 2                      10                RJ
# 3                      10                MT
# 4                      10                RS
# ...                   ...               ...
# 5734                   10                AC
# 5735                   10                SP
# 5736                   10                TO
# 5737                   10                RJ
# 5738                   10                MS
#
# [5739 rows x 8 columns]

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']]
# Out:
#      ocorrencia_classificacao
# 11                   ACIDENTE
# 16                  INCIDENTE
# 18                  INCIDENTE
# 26                  INCIDENTE
# 27                  INCIDENTE
# ...                       ...
# 5693          INCIDENTE GRAVE
# 5694          INCIDENTE GRAVE
# 5704          INCIDENTE GRAVE
# 5730                INCIDENTE
# 5735                INCIDENTE
#
# [1371 rows x 1 columns]

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_uf  \
# 0                  40211                INCIDENTE            RJ
# 1                     20                       20            20
# 2                  40351                INCIDENTE            RJ
# 3                  39527                 ACIDENTE            MT
# 4                  40324                INCIDENTE            RS
# ...                  ...                      ...           ...
# 5734               79769          INCIDENTE GRAVE            AC
# 5735               79804                INCIDENTE            SP
# 5736               79757          INCIDENTE GRAVE            TO
# 5737               79802                INCIDENTE            RJ
# 5738               79756          INCIDENTE GRAVE            MS
#
#      ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0                          2010-01-03 00:00:00        12:00:00
# 1                      20                   20              20
# 2                    SBRJ  2010-01-03 00:00:00        03:00:00
# 3                    ****  2010-01-04 00:00:00        17:30:00
# 4                    SBPK  2010-01-05 00:00:00        19:25:00
# ...                   ...                  ...             ...
# 5734                 SIMB  2020-12-29 00:00:00        18:30:00
# 5735                 SBKP  2020-12-29 00:00:00        19:00:00
# 5736                 ****  2020-12-30 00:00:00        18:30:00
# 5737                 SBGL  2020-12-30 00:00:00        00:54:00
# 5738                 ****  2020-12-31 00:00:00        09:00:00
#
#       total_recomendacoes ocorrencia_uf_bkp
# 0                      10                RJ
# 1                      10                20
# 2                      10                RJ
# 3                      10                MT
# 4                      10                RS
# ...                   ...               ...
# 5734                   10                AC
# 5735                   10                SP
# 5736                   10                TO
# 5737                   10                RJ
# 5738                   10                MS
#
# [5739 rows x 8 columns]

# %%
df.loc[df.ocorrencia_uf == 'SP']
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_uf  \
# 11                 40069                 ACIDENTE            SP
# 16                 39809                INCIDENTE            SP
# 18                 39828                INCIDENTE            SP
# 26                 39847                INCIDENTE            SP
# 27                 39768                INCIDENTE            SP
# ...                  ...                      ...           ...
# 5693               79739          INCIDENTE GRAVE            SP
# 5694               79705          INCIDENTE GRAVE            SP
# 5704               79718          INCIDENTE GRAVE            SP
# 5730               79800                INCIDENTE            SP
# 5735               79804                INCIDENTE            SP
#
#      ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 11                   SBMT  2010-01-10 00:00:00        14:50:00
# 16                   ****  2010-01-15 00:00:00        15:00:00
# 18                   ****  2010-01-15 00:00:00        17:45:00
# 26                   ****  2010-01-20 00:00:00        13:10:00
# 27                   ****  2010-01-21 00:00:00        20:45:00
# ...                   ...                  ...             ...
# 5693                 SBSP  2020-12-03 00:00:00        14:42:00
# 5694                 SDCO  2020-12-04 00:00:00        15:30:00
# 5704                 SBMT  2020-12-11 00:00:00        13:50:00
# 5730                 SBMT  2020-12-28 00:00:00        10:15:00
# 5735                 SBKP  2020-12-29 00:00:00        19:00:00
#
#       total_recomendacoes ocorrencia_uf_bkp
# 11                     10                SP
# 16                     10                SP
# 18                     10                SP
# 26                     10                SP
# 27                     10                SP
# ...                   ...               ...
# 5693                   10                SP
# 5694                   10                SP
# 5704                   10                SP
# 5730                   10                SP
# 5735                   10                SP
#
# [1371 rows x 8 columns]

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_uf  \
# 0               40211                INCIDENTE            RJ
# 1                  20                       20            20
# 2               40351                INCIDENTE            RJ
# 3               39527                 ACIDENTE            MT
# 4               40324                INCIDENTE            RS
#
#   ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0                       2010-01-03 00:00:00        12:00:00
# 1                   20                   20              20
# 2                 SBRJ  2010-01-03 00:00:00        03:00:00
# 3                 ****  2010-01-04 00:00:00        17:30:00
# 4                 SBPK  2010-01-05 00:00:00        19:25:00
#
#    total_recomendacoes ocorrencia_uf_bkp
# 0                   10                RJ
# 1                   10                20
# 2                   10                RJ
# 3                   10                MT
# 4                   10                RS
